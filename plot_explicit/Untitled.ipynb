# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("solvation_energies.csv")
energy_8A3 = df["8A3"]
t = np.linspace(1,50,50)

plt.plot(t, energy_8A3)
plt.show()

# %%
f = np.loadtxt('Atm_surf_dG_env.dat', delimiter=",")
energy_mod_8A3 = f[:,1]
plt.plot(t, energy_mod_8A3)
plt.show()

# %%
mean_dg = df.mean(axis=0)
print(mean_dg)
# Out:
# 8A3   -3776.330960
# 8C2   -3698.782008
# 8E2   -4213.881759
# 8F2   -3639.082629
# 8H2   -3598.297612
# 8I2   -3751.914958
# 8K2   -3884.295417
# 8L2   -3712.246117
# 8M2   -3830.984070
# 8N2   -3755.384536
# 8Q2   -3831.774921
# 8R2   -4124.011882
# 8S2   -3914.071114
# 8T2   -3850.563265
# 8V2   -3622.106088
# 8W2   -3591.891730
# 8Y2   -3685.615531
# dtype: float64
